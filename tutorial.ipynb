# %% [markdown]
# # This tutorial will show users how to perform benchmarking on a new CUB metric.
# This tutorial will compose of two portions:
# 1. In the benchmarking framework, we use NullSeq2.0 to create the random coding sequences. NullSeq2.0 has already been preinstalled in the src/ folder of this package. More information about NullSeq2.0 can be found [here](https://github.com/amarallab/NullSeq2.0). Alternatively, if you do not wish to generate the random sequences from scratch, they are available to download here.
# 2. Determining the performance of the new CUB metric

# %%
# importing NullSeq2.0
import os
import sys
src_dir = os.path.abspath('src')
sys.path[0] = src_dir
import benchmarking.calculate_performance as CP

# %% [markdown]
# ## Determining the performance of CUB metric
# After downloading or creating from scratch the dataset, calculate the CUB of each sequence in the dataset as save it as a csv where one there is one column that is the number of codons used in the sequence named "CUB", and one column that is the calculated CUB for that sequence named "calc_CUB".
#
# For the purposes of this demonstration, we will use Nc as an example. The calculated Nc for each sequence can be found in /data/calculated_Nc

# %%
t = CP.calculate_perfromance('./data/calculated_Nc/')

# %%
CP.compare_performance(t)
